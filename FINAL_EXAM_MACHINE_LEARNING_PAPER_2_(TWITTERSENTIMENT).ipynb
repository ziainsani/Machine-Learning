# %% [markdown]
# <a href="https://colab.research.google.com/github/ziainsani/Machine-Learning/blob/main/Final_Exam_Machine_Learning_Paper_2_(TwitterSentiment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocessing

# %%
# !python2 code/preprocess.py dataset/train-processed.csv #Memanggil Process train dan melakukan train data
# Out:
# Processing 100000/100000
# Saved processed tweets to: dataset/train-processed-processed.csv

# %%
# !python2 code/preprocess.py dataset/test-processed.csv #Memanggil Process test dan melakukan test data
# Out:
# Traceback (most recent call last):
#   File "code/preprocess.py", line 107, in <module>
#     preprocess_csv(csv_file_name, processed_file_name, test_file=False)
#   File "code/preprocess.py", line 81, in preprocess_csv
#     positive = int(line[:line.find(',')])
# ValueError: invalid literal for int() with base 10: 'is so sad for my apl friend'

# %%
# !python2 code/stats.py dataset/train-processed-processed.csv #Data train
# Out:
# Processing 100000/100000
# Calculating frequency distribution
# Saved uni-frequency distribution to dataset/train-processed-processed-freqdist.pkl
# Saved bi-frequency distribution to dataset/train-processed-processed-freqdist-bi.pkl
#
# [Analysis Statistics]
# Tweets => Total: 100000, Positive: 56462, Negative: 43538
# User Mentions => Total: 0, Avg: 0.0000, Max: 0
# URLs => Total: 0, Avg: 0.0000, Max: 0
# Emojis => Total: 0, Positive: 0, Negative: 0, Avg: 0.0000, Max: 0
# Words => Total: 1283269, Unique: 50361, Avg: 12.8327, Max: 41, Min: 0
# Bigrams => Total: 1183437, Unique: 392543, Avg: 11.8344

# %%
# !python2 code/stats.py dataset/test-processed-processed.csv #Data Test baru
# Out:
# Calculating frequency distribution
# Saved uni-frequency distribution to dataset/test-processed-processed-freqdist.pkl
# Saved bi-frequency distribution to dataset/test-processed-processed-freqdist-bi.pkl
#
# [Analysis Statistics]
# Tweets => Total: 0, Positive: 0, Negative: 0
# Traceback (most recent call last):
#   File "code/stats.py", line 106, in <module>
#     print 'User Mentions => Total: %d, Avg: %.4f, Max: %d' % (num_mentions, num_mentions / float(num_tweets), max_mentions)
# ZeroDivisionError: float division by zero

# %%
# !python2 code/baseline.py TRAIN = True #use baseline
# Out:
# Correct = 65.32%

# %%
# !python2 code/naivebayes.py TRAIN = True # Naivebayes Classification
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 7764/10000 = 77.6400 %

# %%
# !python3 code/logistic.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# 2022-01-24 14:44:47.127673: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Iteration 2/180, loss:0.6939, acc:0.47602022-01-24 14:44:49.627644: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 3/180, loss:0.6939, acc:0.51802022-01-24 14:44:49.785268: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 4/180, loss:0.6924, acc:0.53002022-01-24 14:44:49.912675: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 5/180, loss:0.6929, acc:0.54602022-01-24 14:44:50.044289: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 8/180, loss:0.6869, acc:0.63602022-01-24 14:44:50.425212: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 11/180, loss:0.6885, acc:0.60002022-01-24 14:44:50.801372: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 13/180, loss:0.6846, acc:0.64002022-01-24 14:44:51.056648: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 20/180, loss:0.6799, acc:0.64002022-01-24 14:44:51.938609: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 21/180, loss:0.6767, acc:0.69002022-01-24 14:44:52.066018: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration
W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 94/180, loss:0.4448, acc:0.80002022-01-24 14:50:02.539972: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 95/180, loss:0.4124, acc:0.83802022-01-24 14:50:02.664173: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 98/180, loss:0.4124, acc:0.83802022-01-24 14:50:03.052792: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 99/180, loss:0.4118, acc:0.83202022-01-24 14:50:03.186607: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 100/180, loss:0.4171, acc:0.83002022-01-24 14:50:03.309470: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 101/180, loss:0.4515, acc:0.79402022-01-24 14:50:03.447661: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 102/180, loss:0.4451, acc:0.80002022-01-24 14:50:03.568775: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 103/180, loss:0.4322, acc:0.82202022-01-24 14:50:03.689756: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 116/180, loss:0.4293, acc:0.81802022-01-24 14:50:05.328160: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 128/180, loss:0.4173, acc:0.83202022-01-24 14:50:06.839554: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 129/180, loss:0.4282, acc:0.80002022-01-24 14:50:06.972246: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 130/180, loss:0.4317, acc:0.81202022-01-24 14:50:07.092539: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 134/180, loss:0.4118, acc:0.83402022-01-24 14:50:07.599322: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 140/180, loss:0.4093, acc:0.83002022-01-24 14:50:08.354883: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 141/180, loss:0.4084, acc:0.83602022-01-24 14:50:08.473360: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 142/180, loss:0.4102, acc:0.82202022-01-24 14:50:08.605781: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 143/180, loss:0.4431, acc:0.80802022-01-24 14:50:08.726665: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 145/180, loss:0.4137, acc:0.83602022-01-24 14:50:08.976712: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 148/180, loss:0.4286, acc:0.80402022-01-24 14:50:09.370302: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 151/180, loss:0.4039, acc:0.83602022-01-24 14:50:09.743716: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 152/180, loss:0.4129, acc:0.84802022-01-24 14:50:09.863154: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 153/180, loss:0.4442, acc:0.81202022-01-24 14:50:09.991186: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 156/180, loss:0.4189, acc:0.82002022-01-24 14:50:10.371712: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 157/180, loss:0.4299, acc:0.83202022-01-24 14:50:10.491226: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 158/180, loss:0.4182, acc:0.81402022-01-24 14:50:10.628723: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 160/180, loss:0.3917, acc:0.84802022-01-24 14:50:10.892349: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 164/180, loss:0.4024, acc:0.82602022-01-24 14:50:11.387392: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 168/180, loss:0.4120, acc:0.83202022-01-24 14:50:11.901013: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 172/180, loss:0.4267, acc:0.80602022-01-24 14:50:12.398519: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# Iteration 180/180, loss:0.4242, acc:0.81602022-01-24 14:50:13.524714: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:13.647116: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:13.758694: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:13.879134: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:13.996630: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.226657: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.343498: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.470684: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.699055: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.811859: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:14.931299: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.047665: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.161811: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.283798: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.398502: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.517824: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
# 2022-01-24 14:50:15.633718: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
#
# Epoch: 13, val_acc:0.7804
# Testing
# Generating feature vectors
#
#
# Predicting batches
#
# Saved to logistic.csv

# %%
# !python2 code/decisiontree.py TRAIN = True #Klasifikasi dengan decision tree
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 6801/10000 = 68.0100 %

# %%
# !python2 code/randomforest.py TRAIN = True #Klasifikasi dengan Random Forest
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1/usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#
#
# Testing
# Processing 1/1
# Correct: 7203/10000 = 72.0300 %

# %% [markdown]
# Klasifikasi dengan XGBOOST

# %%
import utils
import random
import numpy as np
from xgboost import XGBClassifier
from scipy.sparse import lil_matrix
from sklearn.feature_extraction.text import TfidfTransformer

# Performs classification using XGBoost.


FREQ_DIST_FILE = 'dataset/train-processed-processed-freqdist.pkl'
BI_FREQ_DIST_FILE = 'dataset/train-processed-processed-freqdist-bi.pkl'
TRAIN_PROCESSED_FILE = 'dataset/train-processed-processed.csv'
TEST_PROCESSED_FILE = 'dataset/test-processed-processed.csv'
TRAIN = True
UNIGRAM_SIZE = 1500
VOCAB_SIZE = UNIGRAM_SIZE
USE_BIGRAMS = True
if USE_BIGRAMS:
    BIGRAM_SIZE = 100
    VOCAB_SIZE = UNIGRAM_SIZE + BIGRAM_SIZE
FEAT_TYPE = 'frequency'


def get_feature_vector(tweet):
    uni_feature_vector = []
    bi_feature_vector = []
    words = tweet.split()
    for i in range(len(words) - 1):
        word = words[i]
        next_word = words[i + 1]
        if unigrams.get(word):
            uni_feature_vector.append(word)
        if USE_BIGRAMS:
            if bigrams.get((word, next_word)):
                bi_feature_vector.append((word, next_word))
    if len(words) >= 1:
        if unigrams.get(words[-1]):
            uni_feature_vector.append(words[-1])
    return uni_feature_vector, bi_feature_vector


def extract_features(tweets, batch_size=500, test_file=True, feat_type='presence'):
    num_batches = int(np.ceil(len(tweets) / float(batch_size)))
    for i in range(num_batches):
        batch = tweets[i * batch_size: (i + 1) * batch_size]
        features = lil_matrix((batch_size, VOCAB_SIZE))
        labels = np.zeros(batch_size)
        for j, tweet in enumerate(batch):
            if test_file:
                tweet_words = tweet[1][0]
                tweet_bigrams = tweet[1][1]
            else:
                tweet_words = tweet[2][0]
                tweet_bigrams = tweet[2][1]
                labels[j] = tweet[1]
            if feat_type == 'presence':
                tweet_words = set(tweet_words)
                tweet_bigrams = set(tweet_bigrams)
            for word in tweet_words:
                idx = unigrams.get(word)
                if idx:
                    features[j, idx] += 1
            if USE_BIGRAMS:
                for bigram in tweet_bigrams:
                    idx = bigrams.get(bigram)
                    if idx:
                        features[j, UNIGRAM_SIZE + idx] += 1
        yield features, labels


def apply_tf_idf(X):
    transformer = TfidfTransformer(smooth_idf=True, sublinear_tf=True, use_idf=True)
    transformer.fit(X)
    return transformer


def process_tweets(csv_file, test_file=True):
    """Returns a list of tuples of type (tweet_id, feature_vector)
            or (tweet_id, sentiment, feature_vector)
    Args:
        csv_file (str): Name of processed csv file generated by preprocess.py
        test_file (bool, optional): If processing test file
    Returns:
        list: Of tuples
    """
    tweets = []
    print ('Generating feature vectors')
    with open(csv_file, 'r') as csv:
        lines = csv.readlines()
        total = len(lines)
        for i, line in enumerate(lines):
            if test_file:
                tweet_id, tweet = line.split(',')
            else:
                tweet_id, sentiment, tweet = line.split(',')
            feature_vector = get_feature_vector(tweet)
            if test_file:
                tweets.append((tweet_id, feature_vector))
            else:
                tweets.append((tweet_id, int(sentiment), feature_vector))
            utils.write_status(i + 1, total)
    print ('\n')
    return tweets


if __name__ == '__main__':
    np.random.seed(20)
    unigrams = utils.top_n_words(FREQ_DIST_FILE, UNIGRAM_SIZE)
    if USE_BIGRAMS:
        bigrams = utils.top_n_bigrams(BI_FREQ_DIST_FILE, BIGRAM_SIZE)
    tweets = process_tweets(TRAIN_PROCESSED_FILE, test_file=False)
    if TRAIN:
        train_tweets, val_tweets = utils.split_data(tweets)
    else:
        random.shuffle(tweets)
        train_tweets = tweets
    del tweets
    print ('Extracting features & training batches')
    clf = XGBClassifier(max_depth=25, silent=False, n_estimators=20)
    batch_size = len(train_tweets)
    i = 1
    n_train_batches = int(np.ceil(len(train_tweets) / float(batch_size)))
    for training_set_X, training_set_y in extract_features(train_tweets, test_file=False, feat_type=FEAT_TYPE, batch_size=batch_size):
        utils.write_status(i, n_train_batches)
        i += 1
        if FEAT_TYPE == 'frequency':
            tfidf = apply_tf_idf(training_set_X)
            training_set_X = tfidf.transform(training_set_X)
        clf.fit(training_set_X, training_set_y)
    print ('\n')
    print ('Testing')
    if TRAIN:
        correct, total = 0, len(val_tweets)
        i = 1
        batch_size = len(val_tweets)
        n_val_batches = int(np.ceil(len(val_tweets) / float(batch_size)))
        for val_set_X, val_set_y in extract_features(val_tweets, test_file=False, feat_type=FEAT_TYPE, batch_size=batch_size):
            if FEAT_TYPE == 'frequency':
                val_set_X = tfidf.transform(val_set_X)
            prediction = clf.predict(val_set_X)
            correct += np.sum(prediction == val_set_y)
            utils.write_status(i, n_val_batches)
            i += 1
        print ('\nCorrect: %d/%d = %.4f %%' % (correct, total, correct * 100. / total))
    else:
        del train_tweets
        test_tweets = process_tweets(TEST_PROCESSED_FILE, test_file=True)
        n_test_batches = int(np.ceil(len(test_tweets) / float(batch_size)))
        predictions = np.array([])
        print ('Predicting batches')
        i = 1
        for test_set_X, _ in extract_features(test_tweets, test_file=True, feat_type=FEAT_TYPE):
            if FEAT_TYPE == 'frequency':
                test_set_X = tfidf.transform(test_set_X)
            prediction = clf.predict(test_set_X)
            predictions = np.concatenate((predictions, prediction))
            utils.write_status(i, n_test_batches)
            i += 1
        predictions = [(str(j), int(predictions[j]))
                       for j in range(len(test_tweets))]
        utils.save_results_to_csv(predictions, 'xgboost.csv')
        print ('\nSaved to xgboost.csv')
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 7104/10000 = 71.0400 %

# %%
# !python2 code/svm.py TRAIN = True #model svm
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# Processing 1/1
#
# Testing
# Processing 1/1
# Correct: 7839/10000 = 78.3900 %

# %%
# !python3 code/neuralnet.py TRAIN = True
# Out:
# Generating feature vectors
# Processing 100000/100000
#
# Extracting features & training batches
# 2022-01-24 15:03:47.180094: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Iteration 180/180, loss:0.5244, acc:0.74602022-01-24 15:04:04.519105: W tensorflow/core/data/root_dataset.cc:163] Optimization loop failed: CANCELLED: Operation was cancelled
#
# Epoch: 1, val_acc:0.7635
# Accuracy improved from 0.0000 to 0.7635, saving model
# Iteration 180/180, loss:0.4456, acc:0.7900
# Epoch: 2, val_acc:0.7686
# Accuracy improved from 0.7635 to 0.7686, saving model
# Iteration 180/180, loss:0.4863, acc:0.7760
# Epoch: 3, val_acc:0.7741
# Accuracy improved from 0.7686 to 0.7741, saving model
# Iteration 180/180, loss:0.4366, acc:0.8100
# Epoch: 4, val_acc:0.7693
# Iteration 180/180, loss:0.4413, acc:0.8040
# Epoch: 5, val_acc:0.7715
# Testing
# Generating feature vectors
#
#
# Predicting batches
#
# Saved to 1layerneuralnet.csv

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip #Download file glove.zip
# Out:
# --2022-01-24 15:05:32--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2022-01-24 15:05:32--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2022-01-24 15:05:32--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  4.87MB/s    in 2m 41s
#
# 2022-01-24 15:08:14 (5.09 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
# !unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# !python3 code/lstm.py
# Out:
# Looking for GLOVE vectors
# Processing 400000/0
#
# Found 31735 words in GLOVE
# Generating feature vectors
# Processing 100000/100000
#
# 2022-01-24 15:09:48.086352: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 40, 200)           18000200
#
#  dropout (Dropout)           (None, 40, 200)           0
#
#  lstm (LSTM)                 (None, 128)               168448
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  activation (Activation)     (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 18,176,969
# Trainable params: 18,176,969
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 704/704 [==============================] - 24s 29ms/step - loss: 0.5441 - accuracy: 0.7249 - val_loss: 0.4752 - val_accuracy: 0.7734
# Epoch 2/5
# 704/704 [==============================] - 20s 28ms/step - loss: 0.4613 - accuracy: 0.7858 - val_loss: 0.4683 - val_accuracy: 0.7762
# Epoch 3/5
# 704/704 [==============================] - 20s 28ms/step - loss: 0.4097 - accuracy: 0.8156 - val_loss: 0.4774 - val_accuracy: 0.7808
# Epoch 4/5
# 704/704 [==============================] - 20s 28ms/step - loss: 0.3658 - accuracy: 0.8397 - val_loss: 0.4882 - val_accuracy: 0.7756
# Epoch 5/5
# 704/704 [==============================] - 20s 28ms/step - loss: 0.3258 - accuracy: 0.8571 - val_loss: 0.5151 - val_accuracy: 0.7657

# %%
# !python3 code/cnn.py #CNN Model with 4 Convolution Layer Neural Network
# Out:
# Looking for GLOVE seeds
# Processing 400000/0
#
# Generating feature vectors
# Processing 100000/100000
#
# 2022-01-24 15:12:46.236412: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Epoch 1/8
# 704/704 [==============================] - 46s 53ms/step - loss: 0.5321 - accuracy: 0.7275 - val_loss: 0.4715 - val_accuracy: 0.7701
# Epoch 2/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.4507 - accuracy: 0.7889 - val_loss: 0.4541 - val_accuracy: 0.7817
# Epoch 3/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.4012 - accuracy: 0.8176 - val_loss: 0.5032 - val_accuracy: 0.7522
# Epoch 4/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.3513 - accuracy: 0.8433 - val_loss: 0.4910 - val_accuracy: 0.7732
# Epoch 5/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.3090 - accuracy: 0.8645 - val_loss: 0.5102 - val_accuracy: 0.7730
# Epoch 6/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.2766 - accuracy: 0.8811 - val_loss: 0.5465 - val_accuracy: 0.7746
# Epoch 7/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.2470 - accuracy: 0.8939 - val_loss: 0.5967 - val_accuracy: 0.7697
# Epoch 8/8
# 704/704 [==============================] - 36s 52ms/step - loss: 0.2215 - accuracy: 0.9052 - val_loss: 0.6810 - val_accuracy: 0.7655
